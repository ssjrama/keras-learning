# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# %%
#file_url = "http://storage.googleapis.com/download.tensorflow.org/data/heart.csv"
dataframe = pd.read_csv('fertilizer.csv')

# %%
dataframe.shape
# Out:
# (99, 9)

# %%
dataframe.head()
# Out:
#    Temperature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
val_dataframe = dataframe.sample(frac=0.2, random_state=1337)
train_dataframe = dataframe.drop(val_dataframe.index)

print(
    "Using %d samples for training and %d for validation"
    % (len(train_dataframe), len(val_dataframe))
)
# Out:
# Using 79 samples for training and 20 for validation

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("Fertilizer Name")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds


train_ds = dataframe_to_dataset(train_dataframe)
val_ds = dataframe_to_dataset(val_dataframe)

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'Temperature': <tf.Tensor: shape=(), dtype=int64, numpy=26>, 'Humidity ': <tf.Tensor: shape=(), dtype=int64, numpy=52>, 'Moisture': <tf.Tensor: shape=(), dtype=int64, numpy=36>, 'Soil Type': <tf.Tensor: shape=(), dtype=string, numpy=b'Clayey'>, 'Crop Type': <tf.Tensor: shape=(), dtype=string, numpy=b'Pulses'>, 'Nitrogen': <tf.Tensor: shape=(), dtype=int64, numpy=14>, 'Potassium': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'Phosphorous': <tf.Tensor: shape=(), dtype=int64, numpy=13>}
# Target: tf.Tensor(b'20-20', shape=(), dtype=string)

# %%
train_ds = train_ds.batch(100)
val_ds = val_ds.batch(100)

# %%
#from tensorflow.keras.layers import IntegerLookup
#from tensorflow.keras.layers import Normalization
#from tensorflow.keras.layers import StringLookup


def encode_numerical_feature(feature, name, dataset):
    # Create a Normalization layer for our feature
    normalizer = layers.Normalization()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    encoded_feature = normalizer(feature)
    return encoded_feature


def encode_categorical_feature(feature, name, dataset, is_string):
    lookup_class = layers.StringLookup if is_string else layers.IntegerLookup
    # Create a lookup layer which will turn strings into integer indices
    lookup = lookup_class(output_mode="binary")

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the set of possible string values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the string input into integer indices
    encoded_feature = lookup(feature)
    return encoded_feature

# %%
# Categorical features encoded as integers
# sex = keras.Input(shape=(1,), name="sex", dtype="int64")
# cp = keras.Input(shape=(1,), name="cp", dtype="int64")
# fbs = keras.Input(shape=(1,), name="fbs", dtype="int64")
# restecg = keras.Input(shape=(1,), name="restecg", dtype="int64")
# exang = keras.Input(shape=(1,), name="exang", dtype="int64")
# ca = keras.Input(shape=(1,), name="ca", dtype="int64")

# Categorical feature encoded as string
# thal = keras.Input(shape=(1,), name="thal", dtype="string")

# Numerical features
# age = keras.Input(shape=(1,), name="age")
# trestbps = keras.Input(shape=(1,), name="trestbps")
# chol = keras.Input(shape=(1,), name="chol")
# thalach = keras.Input(shape=(1,), name="thalach")
# oldpeak = keras.Input(shape=(1,), name="oldpeak")
# slope = keras.Input(shape=(1,), name="slope")

Temperature = keras.Input(shape=(1,),name="Temperature")
Humidity = keras.Input(shape=(1,),name="Humidity")
Moisture = keras.Input(shape=(1,),name="Moisture")
Soil_Type = keras.Input(shape=(1,),name="Soil Type")

all_inputs = [
   Soil_Moisture,
   Temperature,
   Humidity,
   Time
]

# Integer categorical features
# sex_encoded = encode_categorical_feature(sex, "sex", train_ds, False)
# cp_encoded = encode_categorical_feature(cp, "cp", train_ds, False)
# fbs_encoded = encode_categorical_feature(fbs, "fbs", train_ds, False)
# restecg_encoded = encode_categorical_feature(restecg, "restecg", train_ds, False)
# exang_encoded = encode_categorical_feature(exang, "exang", train_ds, False)
# ca_encoded = encode_categorical_feature(ca, "ca", train_ds, False)

# String categorical features
# thal_encoded = encode_categorical_feature(thal, "thal", train_ds, True)

# Numerical features
# age_encoded = encode_numerical_feature(age, "age", train_ds)
# trestbps_encoded = encode_numerical_feature(trestbps, "trestbps", train_ds)
# chol_encoded = encode_numerical_feature(chol, "chol", train_ds)
# thalach_encoded = encode_numerical_feature(thalach, "thalach", train_ds)
# oldpeak_encoded = encode_numerical_feature(oldpeak, "oldpeak", train_ds)
# slope_encoded = encode_numerical_feature(slope, "slope", train_ds)

Soil_Moisture_encoded = encode_numerical_feature(
    Soil_Moisture, "Soil_Moisture", train_ds)
Temperature_encoded = encode_numerical_feature(
    Temperature, "Temperature", train_ds)
Humidity_encoded = encode_numerical_feature(
    Humidity, "Humidity", train_ds)
Time_encoded = encode_numerical_feature(
    Time, "Time", train_ds)

all_features = layers.concatenate(
    [
        Soil_Moisture_encoded,
        Temperature_encoded,
        Humidity_encoded,
        Time_encoded,
    ]
)
x = layers.Dense(32, activation="relu")(all_features)
x = layers.Dense(32, activation="relu")(all_features)
x = layers.Dropout(0.5)(x)
output = layers.Dense(1, activation="relu")(x)
model = keras.Model(all_inputs, output)
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-9a8d679ff9c6> in <module>
#      49 # slope_encoded = encode_numerical_feature(slope, "slope", train_ds)
#      50
# ---> 51 Soil_Moisture_encoded = encode_numerical_feature(
#      52     Soil_Moisture, "Soil_Moisture", train_ds)
#      53 Temperature_encoded = encode_numerical_feature(
#
# <ipython-input-11-9092f98dbe11> in encode_numerical_feature(feature, name, dataset)
#       6 def encode_numerical_feature(feature, name, dataset):
#       7     # Create a Normalization layer for our feature
# ----> 8     normalizer = layers.Normalization()
#       9
#      10     # Prepare a Dataset that only yields our feature
#
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Normalization'

# %%
# `rankdir='LR'` is to make the graph horizontal.
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %%
model.fit(train_ds, epochs=100, batch_size=10, validation_data=val_ds)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 5s 5ms/step - loss: 2.0703 - accuracy: 0.5829 - val_loss: 0.7750 - val_accuracy: 0.7190
# Epoch 2/100
# 800/800 [==============================] - 3s 4ms/step - loss: 1.1861 - accuracy: 0.6449 - val_loss: 0.6594 - val_accuracy: 0.7301
# Epoch 3/100
# 800/800 [==============================] - 5s 5ms/step - loss: 0.8421 - accuracy: 0.6604 - val_loss: 0.6285 - val_accuracy: 0.7400
# Epoch 4/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.6937 - accuracy: 0.6571 - val_loss: 0.5462 - val_accuracy: 0.7343
# Epoch 5/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.6337 - accuracy: 0.6639 - val_loss: 0.5365 - val_accuracy: 0.7297
# Epoch 6/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.6045 - accuracy: 0.6818 - val_loss: 0.5140 - val_accuracy: 0.7510
# Epoch 7/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.5847 - accuracy: 0.7043 - val_loss: 0.4893 - val_accuracy: 0.7556
# Epoch 8/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.5605 - accuracy: 0.7189 - val_loss: 0.4731 - val_accuracy: 0.7766
# Epoch 9/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.5352 - accuracy: 0.7389 - val_loss: 0.4475 - val_accuracy: 0.7816
# Epoch 10/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.5109 - accuracy: 0.7403 - val_loss: 0.4322 - val_accuracy: 0.7885
# Epoch 11/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4877 - accuracy: 0.7610 - val_loss: 0.4241 - val_accuracy: 0.7987
# Epoch 12/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4738 - accuracy: 0.7799 - val_loss: 0.3925 - val_accuracy: 0.8227
# Epoch 13/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4483 - accuracy: 0.7982 - val_loss: 0.3763 - val_accuracy: 0.8353
# Epoch 14/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.4356 - accuracy: 0.8050 - val_loss: 0.3863 - val_accuracy: 0.8425
# Epoch 15/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.4340 - accuracy: 0.8103 - val_loss: 0.3896 - val_accuracy: 0.8339
# Epoch 16/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4280 - accuracy: 0.8183 - val_loss: 0.3653 - val_accuracy: 0.8441
# Epoch 17/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4182 - accuracy: 0.8225 - val_loss: 0.3613 - val_accuracy: 0.8433
# Epoch 18/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4092 - accuracy: 0.8255 - val_loss: 0.3576 - val_accuracy: 0.8443
# Epoch 19/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.4064 - accuracy: 0.8267 - val_loss: 0.3454 - val_accuracy: 0.8449
# Epoch 20/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3994 - accuracy: 0.8273 - val_loss: 0.3425 - val_accuracy: 0.8424
# Epoch 21/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.4077 - accuracy: 0.8252 - val_loss: 0.3459 - val_accuracy: 0.8446
# Epoch 22/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4001 - accuracy: 0.8277 - val_loss: 0.3483 - val_accuracy: 0.8475
# Epoch 23/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3941 - accuracy: 0.8280 - val_loss: 0.3737 - val_accuracy: 0.8461
# Epoch 24/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4008 - accuracy: 0.8299 - val_loss: 0.3451 - val_accuracy: 0.8462
# Epoch 25/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3971 - accuracy: 0.8289 - val_loss: 0.3397 - val_accuracy: 0.8428
# Epoch 26/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3945 - accuracy: 0.8316 - val_loss: 0.3375 - val_accuracy: 0.8453
# Epoch 27/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3926 - accuracy: 0.8297 - val_loss: 0.3405 - val_accuracy: 0.8476
# Epoch 28/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3899 - accuracy: 0.8293 - val_loss: 0.3392 - val_accuracy: 0.8424
# Epoch 29/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4034 - accuracy: 0.8166 - val_loss: 0.3390 - val_accuracy: 0.8425
# Epoch 30/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3875 - accuracy: 0.8221 - val_loss: 0.3325 - val_accuracy: 0.8443
# Epoch 31/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3836 - accuracy: 0.8274 - val_loss: 0.3388 - val_accuracy: 0.8479
# Epoch 32/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3884 - accuracy: 0.8252 - val_loss: 0.3464 - val_accuracy: 0.8318
# Epoch 33/100
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3817 - accuracy: 0.8209 - val_loss: 0.3328 - val_accuracy: 0.8412
# Epoch 34/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3831 - accuracy: 0.8273 - val_loss: 0.3265 - val_accuracy: 0.8474
# Epoch 35/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3781 - accuracy: 0.8318 - val_loss: 0.3248 - val_accuracy: 0.8453
# Epoch 36/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3763 - accuracy: 0.8332 - val_loss: 0.3228 - val_accuracy: 0.8468
# Epoch 37/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3804 - accuracy: 0.8303 - val_loss: 0.3229 - val_accuracy: 0.8467
# Epoch 38/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3791 - accuracy: 0.8336 - val_loss: 0.3195 - val_accuracy: 0.8489
# Epoch 39/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4087 - accuracy: 0.8223 - val_loss: 0.3644 - val_accuracy: 0.8365
# Epoch 40/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4039 - accuracy: 0.8195 - val_loss: 0.3415 - val_accuracy: 0.8434
# Epoch 41/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3969 - accuracy: 0.8220 - val_loss: 0.3505 - val_accuracy: 0.8461
# Epoch 42/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3909 - accuracy: 0.8292 - val_loss: 0.3412 - val_accuracy: 0.8461
# Epoch 43/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3885 - accuracy: 0.8317 - val_loss: 0.3289 - val_accuracy: 0.8501
# Epoch 44/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3895 - accuracy: 0.8281 - val_loss: 0.3513 - val_accuracy: 0.8443
# Epoch 45/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3835 - accuracy: 0.8287 - val_loss: 0.3311 - val_accuracy: 0.8473
# Epoch 46/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3831 - accuracy: 0.8329 - val_loss: 0.3301 - val_accuracy: 0.8485
# Epoch 47/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3811 - accuracy: 0.8325 - val_loss: 0.3498 - val_accuracy: 0.8443
# Epoch 48/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3814 - accuracy: 0.8303 - val_loss: 0.3386 - val_accuracy: 0.8437
# Epoch 49/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3742 - accuracy: 0.8281 - val_loss: 0.3239 - val_accuracy: 0.8469
# Epoch 50/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3720 - accuracy: 0.8314 - val_loss: 0.3277 - val_accuracy: 0.8499
# Epoch 51/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3717 - accuracy: 0.8305 - val_loss: 0.3229 - val_accuracy: 0.8475
# Epoch 52/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3711 - accuracy: 0.8327 - val_loss: 0.3223 - val_accuracy: 0.8501
# Epoch 53/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3824 - accuracy: 0.8290 - val_loss: 0.3204 - val_accuracy: 0.8494
# Epoch 54/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3814 - accuracy: 0.8130 - val_loss: 0.3431 - val_accuracy: 0.8072
# Epoch 55/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3859 - accuracy: 0.8041 - val_loss: 0.3362 - val_accuracy: 0.8225
# Epoch 56/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3806 - accuracy: 0.8148 - val_loss: 0.3304 - val_accuracy: 0.8340
# Epoch 57/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3786 - accuracy: 0.8258 - val_loss: 0.3387 - val_accuracy: 0.8482
# Epoch 58/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3741 - accuracy: 0.8314 - val_loss: 0.3251 - val_accuracy: 0.8467
# Epoch 59/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3695 - accuracy: 0.8340 - val_loss: 0.3247 - val_accuracy: 0.8516
# Epoch 60/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3707 - accuracy: 0.8350 - val_loss: 0.3271 - val_accuracy: 0.8469
# Epoch 61/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3767 - accuracy: 0.8332 - val_loss: 0.3203 - val_accuracy: 0.8500
# Epoch 62/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3732 - accuracy: 0.8358 - val_loss: 0.3263 - val_accuracy: 0.8533
# Epoch 63/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3740 - accuracy: 0.8313 - val_loss: 0.3294 - val_accuracy: 0.8462
# Epoch 64/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3716 - accuracy: 0.8353 - val_loss: 0.3224 - val_accuracy: 0.8498
# Epoch 65/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3748 - accuracy: 0.8349 - val_loss: 0.3190 - val_accuracy: 0.8516
# Epoch 66/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3925 - accuracy: 0.8323 - val_loss: 0.3572 - val_accuracy: 0.8447
# Epoch 67/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3882 - accuracy: 0.8303 - val_loss: 0.3312 - val_accuracy: 0.8473
# Epoch 68/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3959 - accuracy: 0.8259 - val_loss: 0.3279 - val_accuracy: 0.8445
# Epoch 69/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3861 - accuracy: 0.8305 - val_loss: 0.3252 - val_accuracy: 0.8483
# Epoch 70/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3789 - accuracy: 0.8304 - val_loss: 0.3235 - val_accuracy: 0.8504
# Epoch 71/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3757 - accuracy: 0.8291 - val_loss: 0.3259 - val_accuracy: 0.8447
# Epoch 72/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3944 - accuracy: 0.8280 - val_loss: 0.3276 - val_accuracy: 0.8482
# Epoch 73/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3798 - accuracy: 0.8304 - val_loss: 0.3427 - val_accuracy: 0.8469
# Epoch 74/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3775 - accuracy: 0.8363 - val_loss: 0.3318 - val_accuracy: 0.8500
# Epoch 75/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3749 - accuracy: 0.8346 - val_loss: 0.3241 - val_accuracy: 0.8505
# Epoch 76/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3707 - accuracy: 0.8336 - val_loss: 0.3421 - val_accuracy: 0.8502
# Epoch 77/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3717 - accuracy: 0.8363 - val_loss: 0.3260 - val_accuracy: 0.8522
# Epoch 78/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4073 - accuracy: 0.8313 - val_loss: 0.3458 - val_accuracy: 0.8449
# Epoch 79/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3953 - accuracy: 0.8298 - val_loss: 0.3344 - val_accuracy: 0.8521
# Epoch 80/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3720 - accuracy: 0.8354 - val_loss: 0.3236 - val_accuracy: 0.8493
# Epoch 81/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3733 - accuracy: 0.8334 - val_loss: 0.3335 - val_accuracy: 0.8484
# Epoch 82/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3658 - accuracy: 0.8341 - val_loss: 0.3234 - val_accuracy: 0.8507
# Epoch 83/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3700 - accuracy: 0.8359 - val_loss: 0.3200 - val_accuracy: 0.8526
# Epoch 84/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3712 - accuracy: 0.8397 - val_loss: 0.3242 - val_accuracy: 0.8522
# Epoch 85/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3829 - accuracy: 0.8301 - val_loss: 0.3460 - val_accuracy: 0.8450
# Epoch 86/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3941 - accuracy: 0.8280 - val_loss: 0.3314 - val_accuracy: 0.8435
# Epoch 87/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3755 - accuracy: 0.8328 - val_loss: 0.3236 - val_accuracy: 0.8519
# Epoch 88/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3753 - accuracy: 0.8313 - val_loss: 0.3212 - val_accuracy: 0.8490
# Epoch 89/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3669 - accuracy: 0.8353 - val_loss: 0.3184 - val_accuracy: 0.8513
# Epoch 90/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3746 - accuracy: 0.8345 - val_loss: 0.3253 - val_accuracy: 0.8494
# Epoch 91/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3671 - accuracy: 0.8385 - val_loss: 0.3138 - val_accuracy: 0.8533
# Epoch 92/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3689 - accuracy: 0.8395 - val_loss: 0.3141 - val_accuracy: 0.8546
# Epoch 93/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3765 - accuracy: 0.8342 - val_loss: 0.3182 - val_accuracy: 0.8443
# Epoch 94/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3727 - accuracy: 0.8290 - val_loss: 0.3378 - val_accuracy: 0.8384
# Epoch 95/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3823 - accuracy: 0.8225 - val_loss: 0.3379 - val_accuracy: 0.8291
# Epoch 96/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3859 - accuracy: 0.8143 - val_loss: 0.3392 - val_accuracy: 0.8288
# Epoch 97/100
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3742 - accuracy: 0.8198 - val_loss: 0.3308 - val_accuracy: 0.8347
# Epoch 98/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3717 - accuracy: 0.8210 - val_loss: 0.3272 - val_accuracy: 0.8373
# Epoch 99/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3678 - accuracy: 0.8239 - val_loss: 0.3227 - val_accuracy: 0.8419
# Epoch 100/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3701 - accuracy: 0.8265 - val_loss: 0.3290 - val_accuracy: 0.8442

# %%
sample = {
    "Soil_Moisture": 50,
    "Temperature": 30,
    "Humidity": 70,
    "Time": 20
}

input_dict = {name: tf.convert_to_tensor(
    [value]) for name, value in sample.items()}
predictions = model.predict(input_dict)

print(
    "Tanaman ini %.1f percent perlu disiram " % (
        100 * predictions[0][0],)
)
# Out:
# Tanaman ini 79.6 percent perlu disiram

# %%
model.save('model.h5')
